# %% [markdown]
# # Set up your environment
#
# Use the mlgeo enviroment from class
#
# Use `requirements.txt` for additional updates

# %%
import numpy as np
import h5py
import os, re, glob
import math
from scipy import signal
from scipy.signal import butter, lfilter
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
import seaborn as sns
import time

import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, MaxPooling1D, UpSampling1D, Flatten, Dropout, Reshape 
from tensorflow.keras.layers import Bidirectional, BatchNormalization, ZeroPadding1D, Conv2DTranspose
from tensorflow.keras.layers import Layer, InputSpec
from tensorflow.keras.models import Model

from tensorflow.keras.optimizers import SGD, Adam, schedules

from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, CSVLogger
from tensorflow.keras.initializers import VarianceScaling

sns.set_style('darkgrid')
sns.set_palette('muted')

sns.set_style('darkgrid')
sns.set_palette('muted')
# Out:
# 2024-11-30 19:01:17.727396: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-30 19:01:17.899804: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733022077.963769    1774 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733022077.987653    1774 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-30 19:01:18.141810: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load data and split train-test

# %%
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset

# Step 1: Load data
print("Beginning to load file...")

# Load the seismic data (adjust file path as needed)
data_file = np.load("Input.npy", mmap_mode='r', allow_pickle=True)

# check the data in Input.npy and see if there are any negative values
print(f'Minimum value in data_file: {data_file.min()}')
print(f'Maximum value in data_file: {data_file.max()}')

print('File loaded')

# Step 2: Split data into train and test sets
#print('Split data into training and testing sets')
#train_data, test_data = train_test_split(data_file, test_size=0.2, random_state=46, shuffle=True)

# split the data into train, testing and validation sets NEW
train_data, temp_data = train_test_split(data_file, test_size=0.3, random_state=46, shuffle=True)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=46, shuffle=True)
# /NEW

print(f'Size of data_file: {data_file.shape}')
print(f'Size of train set (70%): {train_data.shape}')
print(f'Size of test set (15%): {test_data.shape}')
print(f'Size of validation set (15%): {val_data.shape}')  #NEW

# Step 3: Convert the data into PyTorch tensors
train_data_tensor = torch.tensor(train_data, dtype=torch.float32)
test_data_tensor = torch.tensor(test_data, dtype=torch.float32)
val_data_tensor = torch.tensor(val_data, dtype=torch.float32) #NEW

# If the data has more dimensions, you can reshape or modify it as needed, but
# this will depend on the shape of your `Input.npy` file.

# Step 4: Prepare DataLoader for batching
batch_size = 32

# Create TensorDataset and DataLoader for training and testing sets
train_dataset = TensorDataset(train_data_tensor, train_data_tensor)  # (input, target) both are the same for autoencoder
test_dataset = TensorDataset(test_data_tensor, test_data_tensor)
val_dataset = TensorDataset(val_data_tensor, val_data_tensor)  #NEW

# train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# this code doesn't specify a batch size
train_loader = DataLoader(train_dataset, shuffle=True, batch_size=batch_size)
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=batch_size)
val_loader = DataLoader(val_dataset, shuffle=False, batch_size=batch_size)  #NEW

# Data is now ready for training in PyTorch
# Out:
# Beginning to load file...
# Minimum value in data_file: 0.0
# Maximum value in data_file: 11.04010009765625
# File loaded
# Size of data_file: (2328, 96, 128)
# Size of train set (70%): (1629, 96, 128)
# Size of test set (15%): (350, 96, 128)
# Size of validation set (15%): (349, 96, 128)

# %%
# # for each row in Input.npy, display the min and max values

# for i in range (data_file.shape[0]):
#     print (i, np.min(data_file[i]), np.max(data_file[i]))

# %% [markdown]
# Each spectogram is 96x128. This code plots all 96 separate rows on the same plot. The original Input.npy the shape: (2390, 96, 128)

# %%
import matplotlib.pyplot as plt
import numpy as np

data_file = np.load('Input.npy')

# Specify the index of the row you want to plot (for example, row 0)
row_index = 1200 
column_index = 20  # Choose the specific column

plt.figure(figsize=(10, 5))
plt.plot(data_file[row_index, column_index])  # Plot the data at the specified row and column
plt.title(f'Seismic data from station NUPH {row_index}')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()

# %%
# check the data in Input.npy and see if there are any negative values
print(f'Minimum value in data_file: {data_file.min()}')
print(f'Maximum value in data_file: {data_file.max()}')
# Out:
# Minimum value in data_file: 0.0
# Maximum value in data_file: 11.04010009765625

# %% [markdown]
# # Autoencoder architecture construction
#
# Import the dependencies first: `torch`, `torchinfo`

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torchinfo import summary

# Set the seed for reproducibility
sd = 46
torch.manual_seed(sd)

# Function to calculate "same" padding for strided convolutions
def calculate_same_padding(kernel_size, stride):
    return ((stride - 1) + (kernel_size - 1)) // 2

# Define the autoencoder model
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        # Encoder layers with manually calculated "same" padding
        self.conv1 = nn.Conv2d(1, 8, kernel_size=(7, 5), stride=2, padding=(calculate_same_padding(7, 2), calculate_same_padding(5, 2)))
        self.conv2 = nn.Conv2d(8, 16, kernel_size=(5, 3), stride=2, padding=(calculate_same_padding(5, 2), calculate_same_padding(3, 2)))
        self.conv3 = nn.Conv2d(16, 32, kernel_size=(5, 3), stride=2, padding=(calculate_same_padding(5, 2), calculate_same_padding(3, 2)))
        self.conv4 = nn.Conv2d(32, 64, kernel_size=(5, 3), stride=2, padding=(calculate_same_padding(5, 2), calculate_same_padding(3, 2)))

        # Fully connected layers
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 6 * 8, 24)  # Adjusted based on conv output
        self.fc2 = nn.Linear(24, 3072)

        # Decoder layers
        self.fc3 = nn.Linear(3072, 64 * 6 * 8)  # Adjust based on the shape before flattening
        self.conv_transpose1 = nn.ConvTranspose2d(64, 32, kernel_size=(5, 3), stride=2, padding=(2, 1), output_padding=(1, 1))  # Adjust output_padding
        self.conv_transpose2 = nn.ConvTranspose2d(32, 16, kernel_size=(5, 3), stride=2, padding=(2, 1), output_padding=(1, 1))
        self.conv_transpose3 = nn.ConvTranspose2d(16, 8, kernel_size=(5, 3), stride=2, padding=(2, 1), output_padding=(1, 1))
        self.conv_transpose4 = nn.ConvTranspose2d(8, 1, kernel_size=(7, 5), stride=2, padding=(3, 2), output_padding=(1, 1))  # Adjust padding/output_padding

    def forward(self, x):
        # Encoder
        x = F.elu(self.conv1(x))
        x = F.elu(self.conv2(x))
        x = F.elu(self.conv3(x))
        x = F.elu(self.conv4(x))

        # Save shape for later use in decoder
        shape_before_flattening = x.shape

        # Fully connected layers
        x = self.flatten(x)
        encoded = F.elu(self.fc1(x))
        x = F.elu(self.fc2(encoded))

        # Decoder
        x = F.elu(self.fc3(x))
        x = x.view(-1, 64, 6, 8)  # Reshape to the shape before flattening
        x = F.elu(self.conv_transpose1(x))
        x = F.elu(self.conv_transpose2(x))
        x = F.elu(self.conv_transpose3(x))
        decoded = self.conv_transpose4(x)  # No activation for output layer

        return decoded, encoded


# Create model instance
autoencoder = Autoencoder()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the model to the device
autoencoder.to(device)

# Ensure that the input data is on the same device (for example, random input)
dummy_input = torch.randn(1, 1, 96, 128).to(device)  # Simulate a batch of size 1

# Now use torchinfo for the summary
summary(autoencoder, input_size=(1, 1, 96, 128))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Autoencoder                              [1, 1, 96, 128]           --
# ├─Conv2d: 1-1                            [1, 8, 48, 64]            288
# ├─Conv2d: 1-2                            [1, 16, 24, 32]           1,936
# ├─Conv2d: 1-3                            [1, 32, 12, 16]           7,712
# ├─Conv2d: 1-4                            [1, 64, 6, 8]             30,784
# ├─Flatten: 1-5                           [1, 3072]                 --
# ├─Linear: 1-6                            [1, 24]                   73,752
# ├─Linear: 1-7                            [1, 3072]                 76,800
# ├─Linear: 1-8                            [1, 3072]                 9,440,256
# ├─ConvTranspose2d: 1-9                   [1, 32, 12, 16]           30,752
# ├─ConvTranspose2d: 1-10                  [1, 16, 24, 32]           7,696
# ├─ConvTranspose2d: 1-11                  [1, 8, 48, 64]            1,928
# ├─ConvTranspose2d: 1-12                  [1, 1, 96, 128]           281
# ==========================================================================================
# Total params: 9,672,185
# Trainable params: 9,672,185
# Non-trainable params: 0
# Total mult-adds (M): 36.11
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.86
# Params size (MB): 38.69
# Estimated Total Size (MB): 39.60
# ==========================================================================================

# %%
# use torchinfo to visualize the autoencoder
from torchinfo import summary
from torchviz import make_dot
from IPython.display import display, Image

# Print the summary of the model
summary(autoencoder, input_size=(1, 1, 96, 128))

# Create a dummy input tensor
dummy_input = torch.randn(1, 1, 96, 128).to(device)

# Generate the model visualization
try:
    model_vis = make_dot(autoencoder(dummy_input)[0], params=dict(autoencoder.named_parameters()))
    model_vis.format = 'png'
    model_vis.render('autoencoder')
    display(Image(filename='autoencoder.png', width=1000, height=600))
except Exception as e:
    print(f"Error creating or displaying model plot: {e}")

# %% [markdown]
# The `Linear: 1-8 layer` is a fully connected linear layer that flattens the output into 3072 * 3072 parameters. The original keras model reshaped this layer and had 0 parameters.

# %% [markdown]
# # Initial training phase: Pretraining the autoencoder

# %%
start_time = time.time()

import torch
import torch.optim as optim
import torch.nn as nn
from torch.optim.lr_scheduler import ExponentialLR
import pandas as pd

# Define constants
NUM_OF_EPOCHS = 500
initial_lr = 0.001
decay_steps = 1000
decay_rate = 0.5
patience = 30

# Initialize model, optimizer, and scheduler
model = Autoencoder().to(device)
criterion = nn.MSELoss()
#optimizer = optim.Adam(model.parameters(), lr=initial_lr)
optimizer = optim.Adam(model.parameters(), lr=initial_lr, weight_decay=1e-5)  #NEW
scheduler = ExponentialLR(optimizer, gamma=decay_rate**(1 / decay_steps))

# Setup CSV logger
csv_log = {'epoch': [], 'train_loss': [], 'val_loss': [], 'learning_rate': []}

# Early stopping parameters
best_val_loss = float('inf')
early_stop_counter = 0

# Training loop with early stopping and logging
for epoch in range(NUM_OF_EPOCHS):
    # Training phase
    model.train()
    train_loss = 0
    for data, _ in train_loader:
        
        data = data.unsqueeze(1)
        inputs = data.to(device)
        optimizer.zero_grad()
        outputs, _ = model(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    
    # Validation phase
    model.eval()
    val_loss = 0
    with torch.no_grad():
        #for data, _ in test_loader:
        for data, _ in val_loader:  #NEW
            
            data = data.unsqueeze(1)
            inputs = data.to(device)
            outputs, _ = model(inputs)
            loss = criterion(outputs, inputs)
            val_loss += loss.item()

    # Average losses
    train_loss /= len(train_loader)
    #val_loss /= len(test_loader)
    val_loss /= len(val_loader)  #NEW

    # Log values
    current_lr = scheduler.get_last_lr()[0]
    csv_log['epoch'].append(epoch + 1)
    csv_log['train_loss'].append(train_loss)
    csv_log['val_loss'].append(val_loss)
    csv_log['learning_rate'].append(current_lr)

    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        if early_stop_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    # Print progress
    print(f"Epoch {epoch+1}/{NUM_OF_EPOCHS}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, LR: {current_lr:.6f}")

    # Step the learning rate scheduler
    scheduler.step()

# Save the CSV log
pd.DataFrame(csv_log).to_csv('pretrain_log.csv', index=False)

end_time = time.time()
print(f"Pretraining took {end_time - start_time:.2f} seconds")
# Out:
# Epoch 1/500, Train Loss: 0.2040, Val Loss: 0.1003, LR: 0.001000
# Epoch 2/500, Train Loss: 0.0819, Val Loss: 0.0808, LR: 0.000999
# Epoch 3/500, Train Loss: 0.0721, Val Loss: 0.0744, LR: 0.000999
# Epoch 4/500, Train Loss: 0.0672, Val Loss: 0.0710, LR: 0.000998
# Epoch 5/500, Train Loss: 0.0661, Val Loss: 0.0724, LR: 0.000997
# Epoch 6/500, Train Loss: 0.0610, Val Loss: 0.0643, LR: 0.000997
# Epoch 7/500, Train Loss: 0.0575, Val Loss: 0.0604, LR: 0.000996
# Epoch 8/500, Train Loss: 0.0566, Val Loss: 0.0594, LR: 0.000995
# Epoch 9/500, Train Loss: 0.0543, Val Loss: 0.0580, LR: 0.000994
# Epoch 10/500, Train Loss: 0.0530, Val Loss: 0.0564, LR: 0.000994
# Epoch 11/500, Train Loss: 0.0525, Val Loss: 0.0562, LR: 0.000993
# Epoch 12/500, Train Loss: 0.0521, Val Loss: 0.0552, LR: 0.000992
# Epoch 13/500, Train Loss: 0.0515, Val Loss: 0.0560, LR: 0.000992
# Epoch 14/500, Train Loss: 0.0509, Val Loss: 0.0552, LR: 0.000991
# Epoch 15/500, Train Loss: 0.0514, Val Loss: 0.0538, LR: 0.000990
# Epoch 16/500, Train Loss: 0.0508, Val Loss: 0.0544, LR: 0.000990
# Epoch 17/500, Train Loss: 0.0500, Val Loss: 0.0535, LR: 0.000989
# Epoch 18/500, Train Loss: 0.0501, Val Loss: 0.0539, LR: 0.000988
# Epoch 19/500, Train Loss: 0.0496, Val Loss: 0.0531, LR: 0.000988
# Epoch 20/500, Train Loss: 0.0491, Val Loss: 0.0528, LR: 0.000987
# Epoch 21/500, Train Loss: 0.0488, Val Loss: 0.0524, LR: 0.000986
# Epoch 22/500, Train Loss: 0.0489, Val Loss: 0.0524, LR: 0.000986
# Epoch 23/500, Train Loss: 0.0487, Val Loss: 0.0523, LR: 0.000985
# Epoch 24/500, Train Loss: 0.0490, Val Loss: 0.0543, LR: 0.000984
# Epoch 25/500, Train Loss: 0.0502, Val Loss: 0.0534, LR: 0.000984
# Epoch 26/500, Train Loss: 0.0499, Val Loss: 0.0530, LR: 0.000983
# Epoch 27/500, Train Loss: 0.0479, Val Loss: 0.0509, LR: 0.000982
# Epoch 28/500, Train Loss: 0.0472, Val Loss: 0.0509, LR: 0.000981
# Epoch 29/500, Train Loss: 0.0478, Val Loss: 0.0537, LR: 0.000981
# Epoch 30/500, Train Loss: 0.0497, Val Loss: 0.0509, LR: 0.000980
# Epoch 31/500, Train Loss: 0.0471, Val Loss: 0.0503, LR: 0.000979
# Epoch 32/500, Train Loss: 0.0471, Val Loss: 0.0507, LR: 0.000979
# Epoch 33/500, Train Loss: 0.0469, Val Loss: 0.0502, LR: 0.000978
# Epoch 34/500, Train Loss: 0.0464, Val Loss: 0.0498, LR: 0.000977
# Epoch 35/500, Train Loss: 0.0460, Val Loss: 0.0496, LR: 0.000977
# Epoch 36/500, Train Loss: 0.0466, Val Loss: 0.0512, LR: 0.000976
# Epoch 37/500, Train Loss: 0.0474, Val Loss: 0.0503, LR: 0.000975
# Epoch 38/500, Train Loss: 0.0462, Val Loss: 0.0495, LR: 0.000975
# Epoch 39/500, Train Loss: 0.0460, Val Loss: 0.0492, LR: 0.000974
# Epoch 40/500, Train Loss: 0.0455, Val Loss: 0.0491, LR: 0.000973
# Epoch 41/500, Train Loss: 0.0456, Val Loss: 0.0495, LR: 0.000973
# Epoch 42/500, Train Loss: 0.0457, Val Loss: 0.0492, LR: 0.000972
# Epoch 43/500, Train Loss: 0.0475, Val Loss: 0.0521, LR: 0.000971
# Epoch 44/500, Train Loss: 0.0460, Val Loss: 0.0489, LR: 0.000971
# Epoch 45/500, Train Loss: 0.0452, Val Loss: 0.0489, LR: 0.000970
# Epoch 46/500, Train Loss: 0.0453, Val Loss: 0.0489, LR: 0.000969
# Epoch 47/500, Train Loss: 0.0469, Val Loss: 0.0517, LR: 0.000969
# Epoch 48/500, Train Loss: 0.0459, Val Loss: 0.0488, LR: 0.000968
# Epoch 49/500, Train Loss: 0.0452, Val Loss: 0.0489, LR: 0.000967
# Epoch 50/500, Train Loss: 0.0450, Val Loss: 0.0488, LR: 0.000967
# Epoch 51/500, Train Loss: 0.0449, Val Loss: 0.0486, LR: 0.000966
# Epoch 52/500, Train Loss: 0.0449, Val Loss: 0.0488, LR: 0.000965
# Epoch 53/500, Train Loss: 0.0463, Val Loss: 0.0518, LR: 0.000965
# Epoch 54/500, Train Loss: 0.0468, Val Loss: 0.0490, LR: 0.000964
# Epoch 55/500, Train Loss: 0.0454, Val Loss: 0.0490, LR: 0.000963
# Epoch 56/500, Train Loss: 0.0449, Val Loss: 0.0486, LR: 0.000963
# Epoch 57/500, Train Loss: 0.0463, Val Loss: 0.0506, LR: 0.000962
# Epoch 58/500, Train Loss: 0.0466, Val Loss: 0.0493, LR: 0.000961
# Epoch 59/500, Train Loss: 0.0452, Val Loss: 0.0490, LR: 0.000961
# Epoch 60/500, Train Loss: 0.0452, Val Loss: 0.0489, LR: 0.000960
# Epoch 61/500, Train Loss: 0.0447, Val Loss: 0.0487, LR: 0.000959
# Epoch 62/500, Train Loss: 0.0447, Val Loss: 0.0486, LR: 0.000959
# Epoch 63/500, Train Loss: 0.0446, Val Loss: 0.0485, LR: 0.000958
# Epoch 64/500, Train Loss: 0.0446, Val Loss: 0.0485, LR: 0.000957
# Epoch 65/500, Train Loss: 0.0448, Val Loss: 0.0486, LR: 0.000957
# Epoch 66/500, Train Loss: 0.0447, Val Loss: 0.0490, LR: 0.000956
# Epoch 67/500, Train Loss: 0.0446, Val Loss: 0.0485, LR: 0.000955
# Epoch 68/500, Train Loss: 0.0447, Val Loss: 0.0485, LR: 0.000955
# Epoch 69/500, Train Loss: 0.0445, Val Loss: 0.0489, LR: 0.000954
# Epoch 70/500, Train Loss: 0.0447, Val Loss: 0.0490, LR: 0.000953
# Epoch 71/500, Train Loss: 0.0459, Val Loss: 0.0495, LR: 0.000953
# Epoch 72/500, Train Loss: 0.0448, Val Loss: 0.0486, LR: 0.000952
# Epoch 73/500, Train Loss: 0.0451, Val Loss: 0.0495, LR: 0.000951
# Epoch 74/500, Train Loss: 0.0449, Val Loss: 0.0486, LR: 0.000951
# Epoch 75/500, Train Loss: 0.0450, Val Loss: 0.0493, LR: 0.000950
# Epoch 76/500, Train Loss: 0.0455, Val Loss: 0.0488, LR: 0.000949
# Epoch 77/500, Train Loss: 0.0446, Val Loss: 0.0486, LR: 0.000949
# Epoch 78/500, Train Loss: 0.0445, Val Loss: 0.0491, LR: 0.000948
# Epoch 79/500, Train Loss: 0.0446, Val Loss: 0.0487, LR: 0.000947
# Epoch 80/500, Train Loss: 0.0444, Val Loss: 0.0486, LR: 0.000947
# Epoch 81/500, Train Loss: 0.0444, Val Loss: 0.0486, LR: 0.000946
# Epoch 82/500, Train Loss: 0.0442, Val Loss: 0.0488, LR: 0.000945
# Epoch 83/500, Train Loss: 0.0449, Val Loss: 0.0494, LR: 0.000945
# Epoch 84/500, Train Loss: 0.0456, Val Loss: 0.0503, LR: 0.000944
# Epoch 85/500, Train Loss: 0.0459, Val Loss: 0.0493, LR: 0.000943
# Epoch 86/500, Train Loss: 0.0444, Val Loss: 0.0485, LR: 0.000943
# Epoch 87/500, Train Loss: 0.0441, Val Loss: 0.0486, LR: 0.000942
# Epoch 88/500, Train Loss: 0.0441, Val Loss: 0.0486, LR: 0.000941
# Epoch 89/500, Train Loss: 0.0442, Val Loss: 0.0489, LR: 0.000941
# Epoch 90/500, Train Loss: 0.0442, Val Loss: 0.0488, LR: 0.000940
# Epoch 91/500, Train Loss: 0.0442, Val Loss: 0.0489, LR: 0.000940
# Epoch 92/500, Train Loss: 0.0441, Val Loss: 0.0493, LR: 0.000939
# Early stopping at epoch 93
# Pretraining took 39.55 seconds

# %%
# plot training loss and validation loss

import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV log
pretrain_log = pd.read_csv('pretrain_log.csv')

# Plot the training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(pretrain_log['epoch'], pretrain_log['train_loss'], label='Train Loss')
plt.plot(pretrain_log['epoch'], pretrain_log['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Pretraining Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Test the model after training and validation

# %%
# Test the model after training
model.eval()
test_loss = 0.0
with torch.no_grad():
    for data, _ in test_loader:
        data = data.unsqueeze(1)
        inputs = data.to(device)
        outputs, _ = model(inputs)
        loss = criterion(outputs, inputs)
        test_loss += loss.item()

test_loss /= len(test_loader)
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test Loss: 0.0534

# %% [markdown]
# # Evaluate autoencoder reconstruction

# %%
import pandas as pd
df = pd.read_csv('pretrain_log.csv')
fig= plt.figure(figsize=(7, 5))
plt.plot(df['epoch'],df['train_loss'], color='b',label='Training Loss', linewidth=3.0)
plt.plot(df['epoch'],df['val_loss'], color='darkorange',label='Validation Loss', linewidth=3.0)

plt.ylabel('Loss', fontsize= 18)
plt.xlabel('Epoch', fontsize= 18)
plt.title('Reconstruction loss of the autoencoder', fontsize= 18)
plt.yticks (fontsize= 18)
plt.xticks (fontsize= 18)

plt.legend(loc= 1, frameon= False, fontsize= 18)
plt.tight_layout()
plt.show ()
fig.savefig ( 'ReconstructionLoss.png', dpi= 100)

# %%
# Save the model's state_dict
torch.save(model.state_dict(), 'autoencoder-model.pth')

# Re-import or re-define the Autoencoder class
autoencoder = Autoencoder()  # Instantiate the model
autoencoder.load_state_dict(torch.load('autoencoder-model.pth'))  # Load the state_dict

# Move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
autoencoder.to(device)

# Set the model to evaluation mode if you're testing or inferring
autoencoder.eval()
# Out:
# /tmp/ipykernel_1774/434218544.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   autoencoder.load_state_dict(torch.load('autoencoder-model.pth'))  # Load the state_dict
# Autoencoder(
#   (conv1): Conv2d(1, 8, kernel_size=(7, 5), stride=(2, 2), padding=(3, 2))
#   (conv2): Conv2d(8, 16, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#   (conv4): Conv2d(32, 64, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=3072, out_features=24, bias=True)
#   (fc2): Linear(in_features=24, out_features=3072, bias=True)
#   (fc3): Linear(in_features=3072, out_features=3072, bias=True)
#   (conv_transpose1): ConvTranspose2d(64, 32, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#   (conv_transpose2): ConvTranspose2d(32, 16, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#   (conv_transpose3): ConvTranspose2d(16, 8, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#   (conv_transpose4): ConvTranspose2d(8, 1, kernel_size=(7, 5), stride=(2, 2), padding=(3, 2), output_padding=(1, 1))
# )

# %%
data_tensor = torch.tensor(data_file)  # Convert to PyTorch tensor
data_tensor = data_tensor.unsqueeze(1)  # Adds a dimension at position 1

data_tensor.shape
# Out:
# torch.Size([2328, 1, 96, 128])

# %% [markdown]
# ### Autoencoder input-output visualization

# %%
decoded_imgs, _ = autoencoder(data_tensor.float().to(device))

import librosa
import librosa.display

s = 300
e= 305
n = e-s

plt.figure(figsize=(20, 4))
for i in range(s,e):
    
    # Display original
    ax = plt.subplot(2, n, i-s + 1)
    librosa.display.specshow(data_file[i,:,:], alpha=None, cmap='hot', antialiased=True)
    plt.colorbar ()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i-s + 1 + n)
    librosa.display.specshow(decoded_imgs.cpu().detach().numpy()[i,0, :,:], alpha=None, cmap='hot', antialiased=True)
    plt.colorbar ()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt

model.eval()
with torch.no_grad():
    data, _ = next(iter(test_loader))
    data = data.unsqueeze(1).to(device)
    outputs, _ = model(data)
    data, outputs = data.cpu().numpy(), outputs.cpu().numpy()

# Plot original vs reconstructed for a single example
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(data[0].squeeze())
plt.title("Original")
plt.subplot(1, 2, 2)
plt.plot(outputs[0].squeeze())
plt.title("Reconstructed")
plt.show()

# %% [markdown]
# ## Kmeans clustering based on extracted features from the autoencoder

# %%
decoded_imgs, encoded_imgs = autoencoder(data_tensor.float().to(device))

kmeans = KMeans(n_clusters=1, random_state=46, n_init=20).fit(encoded_imgs.cpu().detach().numpy())
y = kmeans.predict(encoded_imgs.cpu().detach().numpy())

def plotter(S, y):
    '''
    function to visualize the outputs of t-SNE
    '''
    
    lw = 2
    # create a scatter plot.
    f = plt.figure(figsize=(22, 10))
    ax = f.add_subplot(111)
    plt.scatter(S[y == 0, 0], S[y == 0, 1],color='navy', alpha=.5, lw=lw, s=100)
    ax.axis('off')
    ax.axis('tight') 
    plt.show()
    f.savefig ('Tnse-km-n1', dpi= 100,bbox_inches = "tight")

    return f, ax

enc = encoded_imgs.cpu().detach().numpy()

from sklearn.manifold import TSNE
redu = TSNE(random_state=123).fit_transform(enc)
plotter(redu, y)
# Out:
# (<Figure size 2200x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Determining optimal number of clusters

# %%
from sklearn.metrics import calinski_harabasz_score
cal = []
K = range(2,16)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=20).fit(encoded_imgs.cpu().detach().numpy())
    labelskm = kmeans.predict(encoded_imgs.cpu().detach().numpy())
    cal.append(calinski_harabasz_score(encoded_imgs.cpu().detach().numpy(), labelskm))
fig= plt.figure(figsize=(7, 5))
plt.plot(K, cal, 'bx-')
plt.xlabel('Number of clusters',fontsize= 18)
plt.ylabel('Calinski-Harabasz score',fontsize= 18)
plt.title('Calinski-Harabasz Score Elbow for K-means Clustering',fontsize= 18)
plt.yticks (fontsize= 18)
plt.xticks (fontsize= 18)
plt.axvline(x=4, color='black', linestyle='--')  # change if this isn't the correct number for your work
plt.tight_layout()
plt.show()
fig.savefig ( 'Calinski score.png', dpi=100)

diff = np.diff(cal)
elbow_point = np.argmin(diff) + 2  # adding 2 because the cluster range K starts at 2
print(f'Elbow point: {elbow_point}')
# Out:
# Elbow point: 3

# %% [markdown]
# # T-sne visualizations of seismic event clusters in feature domain after pretraining

# %%
enc = encoded_imgs.cpu().detach().numpy()
kmeans = KMeans(n_clusters=4, random_state=46, n_init=20).fit(encoded_imgs.cpu().detach().numpy())
y = kmeans.predict(enc)

def plotter(S, y, target_names):
    '''
    function to visualize the outputs of t-SNE
    '''
    # choose a color palette with seaborn.
    colors = [ 'red', 'mediumblue','darkorange','turquoise','lime', 'turquoise', 'darkorange','lawngreen', 'red', 'saddlebrown']
    
    lw = 2
    # create a scatter plot.
    f = plt.figure(figsize=(22, 10))
    ax = f.add_subplot(111)
    for color, i, target_name in zip(colors, [3,0, 1,2], target_names):
        plt.scatter(S[y == i, 0], S[y == i, 1], color=color, alpha=.5, lw=lw, s=100, label=target_name)
    plt.legend(loc='lower left', shadow=False, scatterpoints=1, prop={'size': 26})
    ax.axis('off')
    ax.axis('tight') 
    plt.show()
    f.savefig ('Tnse-km-n4', dpi= 100,bbox_inches = "tight")

    return f, ax

enc = encoded_imgs.cpu().detach().numpy()
from sklearn.manifold import TSNE
redu = TSNE(random_state=123).fit_transform(enc)
target_names = ['cluster 1', 'cluster 2', 'cluster 3', 'cluster 4']
plotter(redu, y, target_names)
# Out:
# (<Figure size 2200x1000 with 1 Axes>, <Axes: >)

# %% [markdown]
# # Loading the pre-trained model

# %%
data_tensor = torch.tensor(data_file)  # Convert to PyTorch tensor
data_tensor = data_tensor.unsqueeze(1).to(device)  # Adds a dimension at position 1


# Assuming autoencoder and data_file are already defined
autoencoder.eval()  # Set to evaluation mode

# Define a dictionary to store layer outputs
layer_outputs = {}

# Function to create hooks for capturing the outputs
def get_layer_output_hook(name):
    def hook(module, input, output):
        layer_outputs[name] = output
    return hook

# Register hooks on each layer you want to capture (starting from layer 1 as in your example)
for idx, layer in enumerate(list(autoencoder.children())[1:], start=1):
    layer.register_forward_hook(get_layer_output_hook(f'layer_{idx}'))

# Run a forward pass with `data_file` to capture the outputs
with torch.no_grad():  # Disable gradient computation
    data = torch.tensor(data_tensor, dtype=torch.float32)  # Convert data_file to tensor
    autoencoder(data)  # Run data through the model to capture intermediate outputs

# Display the outputs
for name, output in layer_outputs.items():
    print(f"{name} output shape: {output.shape}")
# Out:
# layer_1 output shape: torch.Size([2328, 16, 24, 32])
# layer_2 output shape: torch.Size([2328, 32, 12, 16])
# layer_3 output shape: torch.Size([2328, 64, 6, 8])
# layer_4 output shape: torch.Size([2328, 3072])
# layer_5 output shape: torch.Size([2328, 24])
# layer_6 output shape: torch.Size([2328, 3072])
# layer_7 output shape: torch.Size([2328, 3072])
# layer_8 output shape: torch.Size([2328, 32, 12, 16])
# layer_9 output shape: torch.Size([2328, 16, 24, 32])
# layer_10 output shape: torch.Size([2328, 8, 48, 64])
# layer_11 output shape: torch.Size([2328, 1, 96, 128])
# /tmp/ipykernel_1774/174646368.py:23: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data = torch.tensor(data_tensor, dtype=torch.float32)  # Convert data_file to tensor

# %% [markdown]
# # Integrating clustering layer into autoencoder bottleneck

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# Set seed for reproducibility
seed = 46
torch.manual_seed(seed)
np.random.seed(seed)

# Initialize Xavier initializer (same as GlorotUniform in TensorFlow)
initializer = nn.init.xavier_uniform_
n_clusters = 4 # Set desired number of clusters


# Define the clustering layer in PyTorch
class ClusteringLayer(nn.Module):
    def __init__(self, n_clusters, input_dim, alpha=1.0):
        super(ClusteringLayer, self).__init__()
        self.n_clusters = n_clusters
        self.alpha = alpha
        
        # Initialize the cluster centers
        self.clusters = nn.Parameter(torch.Tensor(n_clusters, input_dim))
        # Define cluster centers as a trainable parameter
        
        initializer(self.clusters)  # Xavier initialization

    def forward(self, inputs):
        
        print(inputs.shape)
        self.clusters = self.clusters.to(inputs.device)
        # Compute the soft assignment q
        q = 1.0 / (1.0 + (torch.sum((inputs.unsqueeze(1) - self.clusters) ** 2, dim=2) / self.alpha))
        q = q ** ((self.alpha + 1.0) / 2.0)
        q = q / torch.sum(q, dim=1, keepdim=True)  # Normalize to get probabilities per cluster
        return q

# Define the full model with the clustering layer on top of the autoencoder
class ClusteredAutoencoder(nn.Module):
    def __init__(self, autoencoder, n_clusters):
        super(ClusteredAutoencoder, self).__init__()
        self.autoencoder = autoencoder
        # Clustering layer connected to the output of the encoder
        self.clustering_layer = ClusteringLayer(n_clusters=n_clusters, input_dim=24)  # Match to `encoded` dimension

    def forward(self, x):
        decoded, encoded = self.autoencoder(x)
        q = self.clustering_layer(encoded)  # Cluster assignments
        return decoded, q  # Return both decoded output and cluster assignments

# Instantiate the models
n_clusters = 4  # Set desired number of clusters
model = ClusteredAutoencoder(autoencoder, n_clusters=n_clusters)

# Define the KL-divergence loss function
def kld_loss(q, p):
    return F.kl_div(q.log(), p, reduction='batchmean')

# Example optimizer setup
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# Training loop placeholder
def train(model, data_loader, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        for inputs, _ in data_loader:
            decoded, q = model(inputs)
            # Target distribution p, here using a sample softmax normalization of q as a placeholder
            p = (q ** 2) / torch.sum(q, dim=0)
            p = p / torch.sum(p, dim=1, keepdim=True)
            
            # Calculate the losses
            reconstruction_loss = F.mse_loss(decoded, inputs)   # Measures the element-wise mean squared error
            clustering_loss = kld_loss(q, p)        # Compute the KL Divergence loss.
            total_loss = 0.1 * clustering_loss + reconstruction_loss
            
            # Backward and optimize
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {total_loss.item():.4f}')

# Visualize the model (can be printed or logged)

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the model to the device
model.to(device)

# Ensure that the input data is on the same device (for example, random input)
dummy_input = torch.randn(1, 1, 96, 128).to(device)  # Simulate a batch of size 1

# Now use torchinfo for the summary
summary(model, input_size=(1, 1, 96, 128))
# Out:
# torch.Size([1, 24])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ClusteredAutoencoder                     [1, 1, 96, 128]           --
# ├─Autoencoder: 1-1                       [1, 1, 96, 128]           --
# │    └─Conv2d: 2-1                       [1, 8, 48, 64]            288
# │    └─Conv2d: 2-2                       [1, 16, 24, 32]           1,936
# │    └─Conv2d: 2-3                       [1, 32, 12, 16]           7,712
# │    └─Conv2d: 2-4                       [1, 64, 6, 8]             30,784
# │    └─Flatten: 2-5                      [1, 3072]                 --
# │    └─Linear: 2-6                       [1, 24]                   73,752
# │    └─Linear: 2-7                       [1, 3072]                 76,800
# │    └─Linear: 2-8                       [1, 3072]                 9,440,256
# │    └─ConvTranspose2d: 2-9              [1, 32, 12, 16]           30,752
# │    └─ConvTranspose2d: 2-10             [1, 16, 24, 32]           7,696
# │    └─ConvTranspose2d: 2-11             [1, 8, 48, 64]            1,928
# │    └─ConvTranspose2d: 2-12             [1, 1, 96, 128]           281
# ├─ClusteringLayer: 1-2                   [1, 4]                    96
# ==========================================================================================
# Total params: 9,672,281
# Trainable params: 9,672,281
# Non-trainable params: 0
# Total mult-adds (M): 36.11
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.86
# Params size (MB): 38.69
# Estimated Total Size (MB): 39.60
# ==========================================================================================

# %%
from sklearn.cluster import KMeans
import torch


# Assuming autoencoder and data_file are already defined
data_tensor = torch.tensor(data_file)  # Convert to PyTorch tensor
data_tensor = data_tensor.unsqueeze(1).to(device)  # Adds a dimension at position 1

autoencoder.eval()  # Set to evaluation mode

# Define a dictionary to store layer outputs
layer_outputs = {}

# Function to create hooks for capturing the outputs
def get_layer_output_hook(name):
    def hook(module, input, output):
        layer_outputs[name] = output
    return hook

# Register hooks on each layer you want to capture (starting from layer 1 as in your example)
for idx, layer in enumerate(list(autoencoder.children())[1:], start=1):
    layer.register_forward_hook(get_layer_output_hook(f'layer_{idx}'))

# Run a forward pass with `data_file` to capture the outputs
with torch.no_grad():  # Disable gradient computation
    data = data_tensor.float()  # Ensure data is in float32 format
    autoencoder(data)  # Run data through the model to capture intermediate outputs

# Display the outputs
for name, output in layer_outputs.items():
    print(f"{name} output shape: {output.shape}")
    
    

n_clusters = 4  # Define the number of clusters

# Step 1: Perform KMeans on the encoded output to initialize cluster centers
kmeans = KMeans(n_clusters=n_clusters, random_state=46, n_init=20)
encoded_output = layer_outputs['layer_5'].cpu().detach().numpy()  # Assuming this is the encoded output
y_pred = kmeans.fit_predict(encoded_output)
y_pred_last = np.copy(y_pred)

# Step 2: Set the KMeans cluster centers as initial weights in the clustering layer
cluster_centers = torch.tensor(kmeans.cluster_centers_, dtype=torch.float32, device = device)

# Assuming model.clustering_layer is the clustering layer in the PyTorch model
model.clustering_layer.clusters.data = cluster_centers  # Directly assign cluster centers

# Verify the initialization
print("Number of clusters in KMeans model:", kmeans.n_clusters)
print("Number of clusters in clustering layer:", model.clustering_layer.n_clusters)
print("Assigned KMeans cluster centers as initial weights in the clustering layer.")
# Out:
# layer_1 output shape: torch.Size([2328, 16, 24, 32])
# layer_2 output shape: torch.Size([2328, 32, 12, 16])
# layer_3 output shape: torch.Size([2328, 64, 6, 8])
# layer_4 output shape: torch.Size([2328, 3072])
# layer_5 output shape: torch.Size([2328, 24])
# layer_6 output shape: torch.Size([2328, 3072])
# layer_7 output shape: torch.Size([2328, 3072])
# layer_8 output shape: torch.Size([2328, 32, 12, 16])
# layer_9 output shape: torch.Size([2328, 16, 24, 32])
# layer_10 output shape: torch.Size([2328, 8, 48, 64])
# layer_11 output shape: torch.Size([2328, 1, 96, 128])
# Number of clusters in KMeans model: 4
# Number of clusters in clustering layer: 4
# Assigned KMeans cluster centers as initial weights in the clustering layer.

# %%
model
# Out:
# ClusteredAutoencoder(
#   (autoencoder): Autoencoder(
#     (conv1): Conv2d(1, 8, kernel_size=(7, 5), stride=(2, 2), padding=(3, 2))
#     (conv2): Conv2d(8, 16, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#     (conv3): Conv2d(16, 32, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#     (conv4): Conv2d(32, 64, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1))
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (fc1): Linear(in_features=3072, out_features=24, bias=True)
#     (fc2): Linear(in_features=24, out_features=3072, bias=True)
#     (fc3): Linear(in_features=3072, out_features=3072, bias=True)
#     (conv_transpose1): ConvTranspose2d(64, 32, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#     (conv_transpose2): ConvTranspose2d(32, 16, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#     (conv_transpose3): ConvTranspose2d(16, 8, kernel_size=(5, 3), stride=(2, 2), padding=(2, 1), output_padding=(1, 1))
#     (conv_transpose4): ConvTranspose2d(8, 1, kernel_size=(7, 5), stride=(2, 2), padding=(3, 2), output_padding=(1, 1))
#   )
#   (clustering_layer): ClusteringLayer()
# )

# %%
decoded_imgs  = model(data_tensor.float().to(device))[0]



import librosa
import librosa.display

s = 300
e= 305
n = e-s

plt.figure(figsize=(20, 4))
for i in range(s,e):
    
    # Display original
    ax = plt.subplot(2, n, i-s + 1)
    librosa.display.specshow(data_file[i,:,:], alpha=None, cmap='hot', antialiased=True)
    plt.colorbar ()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i-s + 1 + n)
    librosa.display.specshow(decoded_imgs.cpu().detach().numpy()[i,0, :,:], alpha=None, cmap='hot', antialiased=True)
    plt.colorbar ()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# torch.Size([2328, 24])

# %% [markdown]
# # Finetuning pre-trained model parameters

# %%
import torch
import numpy as np

model.eval()

# Parameters for fine-tuning
batch_size = 32
tol = 0.0001  # tolerance threshold for early stopping
loss_value = 0
index = 0
maxiter = 300
update_interval = 200
index_array = np.arange(data_file.shape[0])
y_pred_last = np.zeros(data_file.shape[0])

data_tensor = torch.tensor(data_file, dtype=torch.float32)
data_tensor = data_tensor.unsqueeze(1).to(device)  # Adds a dimension at position 1

# Define the target distribution function
def target_distribution(q):
    weight = q ** 2 / np.sum(q, axis=0)
    return (weight.T / np.sum(weight, axis=1)).T

# Fine-tuning loop
for ite in range(maxiter):
    print(f"Iteration: {ite}")
    
    # Update clustering target distribution periodically
    if ite % update_interval == 0:
        print("Updating target distribution")
        
        # Forward pass to get cluster assignments
        with torch.no_grad():
            _, q = model(data_tensor)
            q = q.cpu().numpy()  # Convert to numpy for further processing
        
        # Update the target distribution `p`
        p = target_distribution(q)
        y_pred = q.argmax(1)  # Get cluster assignments
        
        # Print loss and clustering information
        print(f"Iter {ite}: ; loss={round(loss_value, 5)}")

        # Check convergence criterion
        delta_label = np.sum(y_pred != y_pred_last).astype(np.float32) / y_pred.shape[0]
        y_pred_last = np.copy(y_pred)
        
        if ite > 0 and delta_label < tol:
            print(f"Convergence achieved: delta_label {delta_label} < tol {tol}")
            break
    
    # Mini-batch training
    start_idx = index * batch_size
    end_idx = min((index + 1) * batch_size, data_file.shape[0])
    idx = index_array[start_idx:end_idx]
    
    batch_data = data_tensor[idx]
    batch_p = torch.tensor(p[idx], dtype=torch.float32, device = device)

    # Zero gradients, forward pass, compute loss, backward pass, and update
    optimizer.zero_grad()
    decoded, q_batch = model(batch_data)
    clustering_loss = F.kl_div(q_batch.log(), batch_p, reduction="batchmean")
    reconstruction_loss = F.mse_loss(decoded, batch_data)
    total_loss = clustering_loss * 0.1 + reconstruction_loss
    total_loss.backward()
    optimizer.step()

    # Update loss and index for next iteration
    loss_value = total_loss.item()
    index = (index + 1) % (data_file.shape[0] // batch_size)
# Out:
# Iteration: 0
# Updating target distribution
# torch.Size([2328, 24])
# Iter 0: ; loss=0
# torch.Size([32, 24])
# Iteration: 1
# torch.Size([32, 24])
# Iteration: 2
# torch.Size([32, 24])
# Iteration: 3
# torch.Size([32, 24])
# Iteration: 4
# torch.Size([32, 24])
# Iteration: 5
# torch.Size([32, 24])
# Iteration: 6
# torch.Size([32, 24])
# Iteration: 7
# torch.Size([32, 24])
# Iteration: 8
# torch.Size([32, 24])
# Iteration: 9
# torch.Size([32, 24])
# Iteration: 10
# torch.Size([32, 24])
# Iteration: 11
# torch.Size([32, 24])
# Iteration: 12
# torch.Size([32, 24])
# Iteration: 13
# torch.Size([32, 24])
# Iteration: 14
# torch.Size([32, 24])
# Iteration: 15
# torch.Size([32, 24])
# Iteration: 16
# torch.Size([32, 24])
# Iteration: 17
# torch.Size([32, 24])
# Iteration: 18
# torch.Size([32, 24])
# Iteration: 19
# torch.Size([32, 24])
# Iteration: 20
# torch.Size([32, 24])
# Iteration: 21
# torch.Size([32, 24])
# Iteration: 22
# torch.Size([32, 24])
# Iteration: 23
# torch.Size([32, 24])
# Iteration: 24
# torch.Size([32, 24])
# Iteration: 25
# torch.Size([32, 24])
# Iteration: 26
# torch.Size([32, 24])
# Iteration: 27
# torch.Size([32, 24])
# Iteration: 28
# torch.Size([32, 24])
# Iteration: 29
# torch.Size([32, 24])
# Iteration: 30
# torch.Size([32, 24])
# Iteration: 31
# torch.Size([32, 24])
# Iteration: 32
# torch.Size([32, 24])
# Iteration: 33
# torch.Size([32, 24])
# Iteration: 34
# torch.Size([32, 24])
# Iteration: 35
# torch.Size([32, 24])
# Iteration: 36
# torch.Size([32, 24])
# Iteration: 37
# torch.Size([32, 24])
# Iteration: 38
# torch.Size([32, 24])
# Iteration: 39
# torch.Size([32, 24])
# Iteration: 40
# torch.Size([32, 24])
# Iteration: 41
# torch.Size([32, 24])
# Iteration: 42
# torch.Size([32, 24])
# Iteration: 43
# torch.Size([32, 24])
# Iteration: 44
# torch.Size([32, 24])
# Iteration: 45
# torch.Size([32, 24])
# Iteration: 46
# torch.Size([32, 24])
# Iteration: 47
# torch.Size([32, 24])
# Iteration: 48
# torch.Size([32, 24])
# Iteration: 49
# torch.Size([32, 24])
# Iteration: 50
# torch.Size([32, 24])
# Iteration: 51
# torch.Size([32, 24])
# Iteration: 52
# torch.Size([32, 24])
# Iteration: 53
# torch.Size([32, 24])
# Iteration: 54
# torch.Size([32, 24])
# Iteration: 55
# torch.Size([32, 24])
# Iteration: 56
# torch.Size([32, 24])
# Iteration: 57
# torch.Size([32, 24])
# Iteration: 58
# torch.Size([32, 24])
# Iteration: 59
# torch.Size([32, 24])
# Iteration: 60
# torch.Size([32, 24])
# Iteration: 61
# torch.Size([32, 24])
# Iteration: 62
# torch.Size([32, 24])
# Iteration: 63
# torch.Size([32, 24])
# Iteration: 64
# torch.Size([32, 24])
# Iteration: 65
# torch.Size([32, 24])
# Iteration: 66
# torch.Size([32, 24])
# Iteration: 67
# torch.Size([32, 24])
# Iteration: 68
# torch.Size([32, 24])
# Iteration: 69
# torch.Size([32, 24])
# Iteration: 70
# torch.Size([32, 24])
# Iteration: 71
# torch.Size([32, 24])
# Iteration: 72
# torch.Size([32, 24])
# Iteration: 73
# torch.Size([32, 24])
# Iteration: 74
# torch.Size([32, 24])
# Iteration: 75
# torch.Size([32, 24])
# Iteration: 76
# torch.Size([32, 24])
# Iteration: 77
# torch.Size([32, 24])
# Iteration: 78
# torch.Size([32, 24])
# Iteration: 79
# torch.Size([32, 24])
# Iteration: 80
# torch.Size([32, 24])
# Iteration: 81
# torch.Size([32, 24])
# Iteration: 82
# torch.Size([32, 24])
# Iteration: 83
# torch.Size([32, 24])
# Iteration: 84
# torch.Size([32, 24])
# Iteration: 85
# torch.Size([32, 24])
# Iteration: 86
# torch.Size([32, 24])
# Iteration: 87
# torch.Size([32, 24])
# Iteration: 88
# torch.Size([32, 24])
# Iteration: 89
# torch.Size([32, 24])
# Iteration: 90
# torch.Size([32, 24])
# Iteration: 91
# torch.Size([32, 24])
# Iteration: 92
# torch.Size([32, 24])
# Iteration: 93
# torch.Size([32, 24])
# Iteration: 94
# torch.Size([32, 24])
# Iteration: 95
# torch.Size([32, 24])
# Iteration: 96
# torch.Size([32, 24])
# Iteration: 97
# torch.Size([32, 24])
# Iteration: 98
# torch.Size([32, 24])
# Iteration: 99
# torch.Size([32, 24])
# Iteration: 100
# torch.Size([32, 24])
# Iteration: 101
# torch.Size([32, 24])
# Iteration: 102
# torch.Size([32, 24])
# Iteration: 103
# torch.Size([32, 24])
# Iteration: 104
# torch.Size([32, 24])
# Iteration: 105
# torch.Size([32, 24])
# Iteration: 106
# torch.Size([32, 24])
# Iteration: 107
# torch.Size([32, 24])
# Iteration: 108
# torch.Size([32, 24])
# Iteration: 109
# torch.Size([32, 24])
# Iteration: 110
# torch.Size([32, 24])
# Iteration: 111
# torch.Size([32, 24])
# Iteration: 112
# torch.Size([32, 24])
# Iteration: 113
# torch.Size([32, 24])
# Iteration: 114
# torch.Size([32, 24])
# Iteration: 115
# torch.Size([32, 24])
# Iteration: 116
# torch.Size([32, 24])
# Iteration: 117
# torch.Size([32, 24])
# Iteration: 118
# torch.Size([32, 24])
# Iteration: 119
# torch.Size([32, 24])
# Iteration: 120
# torch.Size([32, 24])
# Iteration: 121
# torch.Size([32, 24])
# Iteration: 122
# torch.Size([32, 24])
# Iteration: 123
# torch.Size([32, 24])
# Iteration: 124
# torch.Size([32, 24])
# Iteration: 125
# torch.Size([32, 24])
# Iteration: 126
# torch.Size([32, 24])
# Iteration: 127
# torch.Size([32, 24])
# Iteration: 128
# torch.Size([32, 24])
# Iteration: 129
# torch.Size([32, 24])
# Iteration: 130
# torch.Size([32, 24])
# Iteration: 131
# torch.Size([32, 24])
# Iteration: 132
# torch.Size([32, 24])
# Iteration: 133
# torch.Size([32, 24])
# Iteration: 134
# torch.Size([32, 24])
# Iteration: 135
# torch.Size([32, 24])
# Iteration: 136
# torch.Size([32, 24])
# Iteration: 137
# torch.Size([32, 24])
# Iteration: 138
# torch.Size([32, 24])
# Iteration: 139
# torch.Size([32, 24])
# Iteration: 140
# torch.Size([32, 24])
# Iteration: 141
# torch.Size([32, 24])
# Iteration: 142
# torch.Size([32, 24])
# Iteration: 143
# torch.Size([32, 24])
# Iteration: 144
# torch.Size([32, 24])
# Iteration: 145
# torch.Size([32, 24])
# Iteration: 146
# torch.Size([32, 24])
# Iteration: 147
# torch.Size([32, 24])
# Iteration: 148
# torch.Size([32, 24])
# Iteration: 149
# torch.Size([32, 24])
# Iteration: 150
# torch.Size([32, 24])
# Iteration: 151
# torch.Size([32, 24])
# Iteration: 152
# torch.Size([32, 24])
# Iteration: 153
# torch.Size([32, 24])
# Iteration: 154
# torch.Size([32, 24])
# Iteration: 155
# torch.Size([32, 24])
# Iteration: 156
# torch.Size([32, 24])
# Iteration: 157
# torch.Size([32, 24])
# Iteration: 158
# torch.Size([32, 24])
# Iteration: 159
# torch.Size([32, 24])
# Iteration: 160
# torch.Size([32, 24])
# Iteration: 161
# torch.Size([32, 24])
# Iteration: 162
# torch.Size([32, 24])
# Iteration: 163
# torch.Size([32, 24])
# Iteration: 164
# torch.Size([32, 24])
# Iteration: 165
# torch.Size([32, 24])
# Iteration: 166
# torch.Size([32, 24])
# Iteration: 167
# torch.Size([32, 24])
# Iteration: 168
# torch.Size([32, 24])
# Iteration: 169
# torch.Size([32, 24])
# Iteration: 170
# torch.Size([32, 24])
# Iteration: 171
# torch.Size([32, 24])
# Iteration: 172
# torch.Size([32, 24])
# Iteration: 173
# torch.Size([32, 24])
# Iteration: 174
# torch.Size([32, 24])
# Iteration: 175
# torch.Size([32, 24])
# Iteration: 176
# torch.Size([32, 24])
# Iteration: 177
# torch.Size([32, 24])
# Iteration: 178
# torch.Size([32, 24])
# Iteration: 179
# torch.Size([32, 24])
# Iteration: 180
# torch.Size([32, 24])
# Iteration: 181
# torch.Size([32, 24])
# Iteration: 182
# torch.Size([32, 24])
# Iteration: 183
# torch.Size([32, 24])
# Iteration: 184
# torch.Size([32, 24])
# Iteration: 185
# torch.Size([32, 24])
# Iteration: 186
# torch.Size([32, 24])
# Iteration: 187
# torch.Size([32, 24])
# Iteration: 188
# torch.Size([32, 24])
# Iteration: 189
# torch.Size([32, 24])
# Iteration: 190
# torch.Size([32, 24])
# Iteration: 191
# torch.Size([32, 24])
# Iteration: 192
# torch.Size([32, 24])
# Iteration: 193
# torch.Size([32, 24])
# Iteration: 194
# torch.Size([32, 24])
# Iteration: 195
# torch.Size([32, 24])
# Iteration: 196
# torch.Size([32, 24])
# Iteration: 197
# torch.Size([32, 24])
# Iteration: 198
# torch.Size([32, 24])
# Iteration: 199
# torch.Size([32, 24])
# Iteration: 200
# Updating target distribution
# torch.Size([2328, 24])
# Iter 200: ; loss=0.03995
# torch.Size([32, 24])
# Iteration: 201
# torch.Size([32, 24])
# Iteration: 202
# torch.Size([32, 24])
# Iteration: 203
# torch.Size([32, 24])
# Iteration: 204
# torch.Size([32, 24])
# Iteration: 205
# torch.Size([32, 24])
# Iteration: 206
# torch.Size([32, 24])
# Iteration: 207
# torch.Size([32, 24])
# Iteration: 208
# torch.Size([32, 24])
# Iteration: 209
# torch.Size([32, 24])
# Iteration: 210
# torch.Size([32, 24])
# Iteration: 211
# torch.Size([32, 24])
# Iteration: 212
# torch.Size([32, 24])
# Iteration: 213
# torch.Size([32, 24])
# Iteration: 214
# torch.Size([32, 24])
# Iteration: 215
# torch.Size([32, 24])
# Iteration: 216
# torch.Size([32, 24])
# Iteration: 217
# torch.Size([32, 24])
# Iteration: 218
# torch.Size([32, 24])
# Iteration: 219
# torch.Size([32, 24])
# Iteration: 220
# torch.Size([32, 24])
# Iteration: 221
# torch.Size([32, 24])
# Iteration: 222
# torch.Size([32, 24])
# Iteration: 223
# torch.Size([32, 24])
# Iteration: 224
# torch.Size([32, 24])
# Iteration: 225
# torch.Size([32, 24])
# Iteration: 226
# torch.Size([32, 24])
# Iteration: 227
# torch.Size([32, 24])
# Iteration: 228
# torch.Size([32, 24])
# Iteration: 229
# torch.Size([32, 24])
# Iteration: 230
# torch.Size([32, 24])
# Iteration: 231
# torch.Size([32, 24])
# Iteration: 232
# torch.Size([32, 24])
# Iteration: 233
# torch.Size([32, 24])
# Iteration: 234
# torch.Size([32, 24])
# Iteration: 235
# torch.Size([32, 24])
# Iteration: 236
# torch.Size([32, 24])
# Iteration: 237
# torch.Size([32, 24])
# Iteration: 238
# torch.Size([32, 24])
# Iteration: 239
# torch.Size([32, 24])
# Iteration: 240
# torch.Size([32, 24])
# Iteration: 241
# torch.Size([32, 24])
# Iteration: 242
# torch.Size([32, 24])
# Iteration: 243
# torch.Size([32, 24])
# Iteration: 244
# torch.Size([32, 24])
# Iteration: 245
# torch.Size([32, 24])
# Iteration: 246
# torch.Size([32, 24])
# Iteration: 247
# torch.Size([32, 24])
# Iteration: 248
# torch.Size([32, 24])
# Iteration: 249
# torch.Size([32, 24])
# Iteration: 250
# torch.Size([32, 24])
# Iteration: 251
# torch.Size([32, 24])
# Iteration: 252
# torch.Size([32, 24])
# Iteration: 253
# torch.Size([32, 24])
# Iteration: 254
# torch.Size([32, 24])
# Iteration: 255
# torch.Size([32, 24])
# Iteration: 256
# torch.Size([32, 24])
# Iteration: 257
# torch.Size([32, 24])
# Iteration: 258
# torch.Size([32, 24])
# Iteration: 259
# torch.Size([32, 24])
# Iteration: 260
# torch.Size([32, 24])
# Iteration: 261
# torch.Size([32, 24])
# Iteration: 262
# torch.Size([32, 24])
# Iteration: 263
# torch.Size([32, 24])
# Iteration: 264
# torch.Size([32, 24])
# Iteration: 265
# torch.Size([32, 24])
# Iteration: 266
# torch.Size([32, 24])
# Iteration: 267
# torch.Size([32, 24])
# Iteration: 268
# torch.Size([32, 24])
# Iteration: 269
# torch.Size([32, 24])
# Iteration: 270
# torch.Size([32, 24])
# Iteration: 271
# torch.Size([32, 24])
# Iteration: 272
# torch.Size([32, 24])
# Iteration: 273
# torch.Size([32, 24])
# Iteration: 274
# torch.Size([32, 24])
# Iteration: 275
# torch.Size([32, 24])
# Iteration: 276
# torch.Size([32, 24])
# Iteration: 277
# torch.Size([32, 24])
# Iteration: 278
# torch.Size([32, 24])
# Iteration: 279
# torch.Size([32, 24])
# Iteration: 280
# torch.Size([32, 24])
# Iteration: 281
# torch.Size([32, 24])
# Iteration: 282
# torch.Size([32, 24])
# Iteration: 283
# torch.Size([32, 24])
# Iteration: 284
# torch.Size([32, 24])
# Iteration: 285
# torch.Size([32, 24])
# Iteration: 286
# torch.Size([32, 24])
# Iteration: 287
# torch.Size([32, 24])
# Iteration: 288
# torch.Size([32, 24])
# Iteration: 289
# torch.Size([32, 24])
# Iteration: 290
# torch.Size([32, 24])
# Iteration: 291
# torch.Size([32, 24])
# Iteration: 292
# torch.Size([32, 24])
# Iteration: 293
# torch.Size([32, 24])
# Iteration: 294
# torch.Size([32, 24])
# Iteration: 295
# torch.Size([32, 24])
# Iteration: 296
# torch.Size([32, 24])
# Iteration: 297
# torch.Size([32, 24])
# Iteration: 298
# torch.Size([32, 24])
# Iteration: 299
# torch.Size([32, 24])

# %% [markdown]
# # T-sne visualizations of seismic event clusters in feature domain after finetuning

# %%
autoencoder.eval()  # Set to evaluation mode

# Define a dictionary to store layer outputs
layer_outputs = {}

# Function to create hooks for capturing the outputs
def get_layer_output_hook(name):
    def hook(module, input, output):
        layer_outputs[name] = output
    return hook

# Register hooks on each layer you want to capture (starting from layer 1 as in your example)
for idx, layer in enumerate(list(autoencoder.children())[1:], start=1):
    layer.register_forward_hook(get_layer_output_hook(f'layer_{idx}'))

# Run a forward pass with `data_file` to capture the outputs
with torch.no_grad():  # Disable gradient computation
    data = data_tensor.float()  # Ensure data is in float32 format
    autoencoder(data)  # Run data through the model to capture intermediate outputs

y=y_pred

def plotter(S, y, target_names):
    '''
    function to visualize the outputs of t-SNE
    '''
    # choose a color palette with seaborn.
    colors = ['red', 'mediumblue','darkorange','turquoise', 'lawngreen', 'red', 'saddlebrown']
    
    lw = 2
    # create a scatter plot.
    f = plt.figure(figsize=(22, 10))
    ax = f.add_subplot(111)
    for color, i, target_name in zip(colors, [3,0, 1,2], target_names):
        plt.scatter(S[y == i, 0], S[y == i, 1], color=color, alpha=0.5, lw=lw, s=100, label=target_name)
    plt.legend(loc='lower left', shadow=False, scatterpoints=1, prop={'size': 26})
    ax.axis('off')
    ax.axis('tight') 
    plt.show()
    f.savefig ('Tsne-km-n4-ft.png', dpi= 100,bbox_inches = "tight")
    
    return f, ax


enc = layer_outputs['layer_5'].cpu().detach().numpy()

print(f'Number of NaNs in encoded output: {np.isnan(enc).sum()}')
print(f'amount of encoded output: {enc.shape}')
print(f'amount of NOT NaNs in encoded output: {np.count_nonzero(~np.isnan(enc))}')

from sklearn.manifold import TSNE
redu = TSNE(random_state=123).fit_transform(enc)
target_names = [ 'Earthquakes (EQ)','Continuous tremors 1 (CT1)', 'Episodic tremors (ET)', 'Continuous tremors 2 (CT2)' ]
plotter(redu, y, target_names)
# Out:
# Number of NaNs in encoded output: 0
# amount of encoded output: (2328, 24)
# amount of NOT NaNs in encoded output: 55872
# (<Figure size 2200x1000 with 1 Axes>, <Axes: >)

# %%
### Save the labels
np.savetxt('km-n4-ft.txt', y, fmt='%i', delimiter=',')

# Change the order of the cluster numbers (just for a nice representation)

with open('km-n4-ft.txt', 'r') as file :
  filedata = file.read()

# Replace the target string
filedata = filedata.replace('3', 'data_file')
filedata = filedata.replace('2', '3')
filedata = filedata.replace('1', '2')
filedata = filedata.replace('0', '1')
filedata = filedata.replace('data_file', '0')

# Re-write the output
with open('km-n4-ft.txt', 'w') as file:
  file.write(filedata)

# %% [markdown]
# ### Visualizing cluster changes across time

# %%
## Visualize the temporal changes in the clusters
## adapted from original code to deal with different size datasets

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# Load the data (update the file name as needed)
y = np.loadtxt('km-n4-ft.txt')

# Dynamically generate x1 based on the size of y
x1 = np.arange(len(y))

# Define the colormap
colors = ['red', 'mediumblue', 'darkorange', 'turquoise']
cmap_name = 'my_list'
cmap = LinearSegmentedColormap.from_list(cmap_name, colors)

# Create the figure
fig = plt.figure(figsize=(18, 4))
ax = fig.add_subplot()

# Display size of x1 and y
print(f'x1 = {len(x1)} \n y = {len(y)}')

# Scatter plot
sc = ax.scatter(x1, y, c=y, cmap=cmap, s=30, alpha=0.2)

# Set y-ticks dynamically
unique_labels = np.unique(y).astype(int)
ax.set_yticks(unique_labels)
ax.set_yticklabels([f'Cluster {label}' for label in unique_labels], fontsize=18)
plt.ylabel('Clusters', fontsize=18)

# Dynamically set x-ticks
n_ticks = 10  # Define the number of x-ticks
x_ticks = np.linspace(0, len(x1) - 1, n_ticks, dtype=int)
# x_tick_labels = [f'Day {i}' for i in range(n_ticks)]
#x_tick_labels = ''
ax.set_xticks(x_ticks)
#ax.set_xticklabels(x_tick_labels, fontsize=16)

# Example vertical lines (adjust dynamically if needed)
vertical_lines = [x_ticks[1], x_ticks[4], x_ticks[7]]
for vline in vertical_lines:
    ax.axvline(x=vline, linewidth=4, color='black')

# Set x-limits (optionally zoom into a specific range)
plt.xlim(0, len(x1) - 1)  # Full range
# plt.xlim(980, 1020)  # Zoomed-in range (optional)

plt.tight_layout()

# Save the figure
fig.savefig('Temporal_Cluster_Changes.png', dpi=100)
# Out:
# x1 = 2328
#  y = 2328

# %%
### ORIGINAL CODE SPECIFIC TO THE ORIGINAL DATASET ###

# from matplotlib.colors import LinearSegmentedColormap

# y= np.loadtxt ('km-n4-ft.txt')
# fig= plt.figure(figsize=(18, 4))
# ax = fig.add_subplot()
# x1=list(range(0,2390))
# colors = ['red', 'mediumblue','darkorange','turquoise']
# cmap_name = 'my_list'
# cmap = LinearSegmentedColormap.from_list(cmap_name, colors)

# # display size of x1 and y
# #print(f'x1 = {len(x1)} \n y = {len(y)}')

# ax.scatter (x1, y, c=y, cmap=cmap, s= 30, alpha=0.2)
# ax.set_yticks ([0, 1, 2,3])
# ax.set_yticklabels (['EQ','CT1', 'ET','CT2'], fontsize=18)
# plt.ylabel('Clusters', fontsize= 18)

# ax.set_xticks ([0,175,417,708,996,1117,1425,1782,2142,2390])
# ax.set_xticklabels (['12 March','19 March','30 March','15 April','27 April','2 May','15 May','30 May','14 June','24 June'], fontsize=16)
# ax.axvline (x=174, linewidth=4, color='black')
# ax.axvline (x=996, linewidth=4, color='black')
# ax.axvline (x=2127, linewidth=4, color='black')

# plt.xlim (0,2390)
# plt.xlim (980,1020)
# plt.tight_layout()
# fig.savefig ( 'Temporal Cluster Changes.png', dpi= 100)

# %% [raw]
# x1 = 2390 -> number of samples in original dataset
# y = 670 -> number of samples in the current dataset

# %% [markdown]
# # Cluster-wise autoencoder input-output visualization

# %%
decoded_imgs[43,:,:,:].shape
# Out:
# torch.Size([1, 96, 128])

# %% [markdown]
# The following cell plots images from data locations specific to the original paper. It is included here for reference, but it is not currently correct for other data sets.

# %% [raw]
# import librosa
# import librosa.display
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import savefig
# import matplotlib.gridspec as gridspec
#
# decoded_imgs, _ = autoencoder(data_tensor.float().to(device))
# decoded_imgs = decoded_imgs.cpu().detach().numpy()
#
# fig= plt.figure(figsize=(15, 5))
# spec = gridspec.GridSpec(2, 3)
#
# ax1 = fig.add_subplot(spec[0, 0])
#
# librosa.display.specshow(data_file[43,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax1.set(ylabel=None)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax2 = fig.add_subplot(spec[0, 1])
#
# librosa.display.specshow(data_file[44,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks ([])
# ax2.set(ylabel=None)
#
# fig.suptitle ('Cluster EQ', fontsize= 22)
#
# ax3 = fig.add_subplot(spec[0, 2])
#
# librosa.display.specshow(data_file[45,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks ([])
# ax3.set(ylabel=None)
#
# ax4 = fig.add_subplot(spec[1, 0])
#
# librosa.display.specshow(decoded_imgs[43,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax4.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax5 = fig.add_subplot(spec[1, 1])
#
# librosa.display.specshow(decoded_imgs[44,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks ([])
# ax5.set(ylabel=None)
# ax5.set_xlabel("Time (min)", fontsize= 18)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize=18)
#
# ax6 = fig.add_subplot(spec[1, 2])
#
# librosa.display.specshow(decoded_imgs[45,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks ([])
# ax6.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# plt.tight_layout()
# plt.savefig ('In&out-EQ.png', dpi=100, bbox_inches = "tight")
# plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
import matplotlib.gridspec as gridspec
import numpy as np

# Function to create a single spectrogram plot
def plot_spectrogram(ax, data, index, cmap='hot', vmin=-1, vmax=10, sr=8, freq_ticks=None, freq_labels=None, x_ticks=None, x_labels=None, ylabel=None, xlabel=None):
    """
    Plot a spectrogram on the provided axis.

    Args:
        ax: The axis to plot on.
        data: 3D array of spectrogram data.
        index: Index of the spectrogram slice to plot.
        cmap: Colormap for the plot.
        vmin: Minimum value for the color scale.
        vmax: Maximum value for the color scale.
        sr: Sampling rate.
        freq_ticks: Y-tick positions.
        freq_labels: Y-tick labels.
        x_ticks: X-tick positions.
        x_labels: X-tick labels.
        ylabel: Label for the y-axis.
        xlabel: Label for the x-axis.
    """
    librosa.display.specshow(data[index, :, :], cmap=cmap, antialiased=True, y_axis='linear', sr=sr, vmin=vmin, vmax=vmax, ax=ax)
    cbar = plt.colorbar(ax=ax, pad=0.03)
    cbar.ax.tick_params(labelsize=18, rotation=0)
    if freq_ticks and freq_labels:
        ax.set_yticks(freq_ticks)
        ax.set_yticklabels(freq_labels, fontsize=18)
    if x_ticks and x_labels:
        ax.set_xticks(x_ticks)
        ax.set_xticklabels(x_labels, fontsize=18)
    if ylabel:
        ax.set_ylabel(ylabel, fontsize=18)
    if xlabel:
        ax.set_xlabel(xlabel, fontsize=18)

# %% [raw]
# fig= plt.figure(figsize=(15, 5))
# spec = gridspec.GridSpec(2, 3)
#
# ax1 = fig.add_subplot(spec[0, 0])
#
# librosa.display.specshow(data_file[353,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax1.set(ylabel=None)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax2 = fig.add_subplot(spec[0, 1])
#
# librosa.display.specshow(data_file[354,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax2.set(ylabel=None)
#
# fig.suptitle ('Cluster CT1', fontsize= 22)
#
# ax3 = fig.add_subplot(spec[0, 2])
#
# librosa.display.specshow(data_file[355,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax3.set(ylabel=None)
#
# ax4 = fig.add_subplot(spec[1, 0])
#
# librosa.display.specshow(decoded_imgs[353,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax4.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax5 = fig.add_subplot(spec[1, 1])
#
# librosa.display.specshow(decoded_imgs[354,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax5.set(ylabel=None)
# ax5.set_xlabel("Time (min)", fontsize= 18)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# ax6 = fig.add_subplot(spec[1, 2])
#
# librosa.display.specshow(decoded_imgs[355,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax6.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# plt.tight_layout()
# plt.savefig ('In&out-CT1.png', dpi=100)
# plt.show()

# %% [raw]
# # ORIGINAL PLOTTING CODE ##
#
# import librosa
# import librosa.display
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import savefig
# import matplotlib.gridspec as gridspec
#
#
# fig= plt.figure(figsize=(15, 5))
# spec = gridspec.GridSpec(2, 3)
#
# # Plot 1
# ax1 = fig.add_subplot(spec[0, 0])
#
# librosa.display.specshow(data_file[1169,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax1.set(ylabel=None)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# # Plot 2
# ax2 = fig.add_subplot(spec[0, 1])
#
# librosa.display.specshow(data_file[1170,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax2.set(ylabel=None)
#
# fig.suptitle ('Cluster ET', fontsize= 22)
#
# # Plot 3
# ax3 = fig.add_subplot(spec[0, 2])
#
# librosa.display.specshow(data_file[1171,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax3.set(ylabel=None)
#
# # Plot 4
# ax4 = fig.add_subplot(spec[1, 0])
#
# librosa.display.specshow(decoded_imgs[1169,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax4.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# # Plot 5
# ax5 = fig.add_subplot(spec[1, 1])
#
# librosa.display.specshow(decoded_imgs[1170,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax5.set(ylabel=None)
# ax5.set_xlabel("Time (min)", fontsize= 20)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# # Plot 6
# ax6 = fig.add_subplot(spec[1, 2])
#
# librosa.display.specshow(decoded_imgs[1171,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax6.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# plt.tight_layout()
# plt.savefig ('In&out-ET.png', dpi=100)
# plt.show()

# %% [raw]
# import librosa
# import librosa.display
# import matplotlib.pyplot as plt
# from matplotlib.pyplot import savefig
# import matplotlib.gridspec as gridspec
#
#
# fig= plt.figure(figsize=(15, 5))
# spec = gridspec.GridSpec(2, 3)
#
# ax1 = fig.add_subplot(spec[0, 0])
#
# librosa.display.specshow(data_file[2342,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax1.set(ylabel=None)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax2 = fig.add_subplot(spec[0, 1])
#
# librosa.display.specshow(data_file[2343,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax2.set(ylabel=None)
#
# fig.suptitle ('Cluster CT2', fontsize= 22)
#
# ax3 = fig.add_subplot(spec[0, 2])
#
# librosa.display.specshow(data_file[2344,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax3.set(ylabel=None)
#
# ax4 = fig.add_subplot(spec[1, 0])
#
# librosa.display.specshow(decoded_imgs[2342,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax4.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
# plt.ylabel('Frequency (Hz)', fontsize= 18)
#
# ax5 = fig.add_subplot(spec[1, 1])
#
# librosa.display.specshow(decoded_imgs[2343,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax5.set(ylabel=None)
# ax5.set_xlabel("Time (min)", fontsize= 20)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# ax6 = fig.add_subplot(spec[1, 2])
#
# librosa.display.specshow(decoded_imgs[2344,0,:,:], alpha=None, cmap='hot', antialiased=True,y_axis='linear', sr= 8, vmin=-1 , vmax=10)
# cbar= plt.colorbar(pad= 0.03)
# cbar.ax.tick_params(labelsize=18, rotation=0)
# freq =[0,1.33, 2.66, 4]
# labelsy = [1,2,3, 4]
# plt.yticks (freq, labelsy, fontsize= 18)
# ax6.set(ylabel=None)
# labelsx = [0,30,60]
# plt.xticks(np.arange(0,128, 63.999), labelsx, fontsize= 18)
#
# plt.tight_layout()
# plt.savefig ('In&out-CT2.png', dpi=100)
# plt.show()
